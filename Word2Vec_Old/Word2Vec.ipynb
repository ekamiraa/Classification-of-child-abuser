# %%
import numpy as np
import pandas as pd
import collections
from collections import defaultdict

# %% [markdown]
# ## Read File

# %%
filename = "Preprocessing/Sample Dataset Preprocessing.csv"

# %%
df = pd.read_csv(filename, header=0)
df.head(10)
# Out:
#                                               Berita            Label  \
# 0  ['perkosa', 'anak', 'kandung', 'pria', 'dompu'...         keluarga
# 1  ['pria', 'cabul', 'anak', 'lelaki', 'rumdis', ...      orang asing
# 2  ['muncul', 'klarifikasi', 'duga', 'salur', 'pe...         pengasuh
# 3  ['heboh', 'video', 'gadis', 'ditelanjangidipuk...      orang asing
# 4  ['satria', 'mahathir', 'cogil', 'sangka', 'ker...            teman
# 5  ['yasin', 'ringkus', 'lapor', 'istri', 'perkos...         keluarga
# 6  ['viral', 'ayah', 'probolinggo', 'banting', 'a...         keluarga
# 7  ['video', 'keras', 'murid', 'smp', 'cilacap', ...            teman
# 8  ['guruortu', 'bikin', 'petisi', 'kepala', 'sma...  tenaga pendidik
# 9  ['polisi', 'periksa', 'duga', 'laku', 'rundung...            teman
#
#    Category_id
# 0            0
# 1            4
# 2            1
# 3            4
# 4            3
# 5            0
# 6            0
# 7            3
# 8            2
# 9            3

# %%
df['Berita'].apply(type).value_counts()
# Out:
# Berita
# <class 'str'>    49
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Berita         object
# Label          object
# Category_id     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Berita       49 non-null     object
#  1   Label        49 non-null     object
#  2   Category_id  49 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# ### Parse the strings into lists

# %%
import ast
df['Berita'] = df['Berita'].apply(ast.literal_eval)

df['Berita'].head()
# Out:
# 0    [perkosa, anak, kandung, pria, dompu, tangkap,...
# 1    [pria, cabul, anak, lelaki, rumdis, wabup, lan...
# 2    [muncul, klarifikasi, duga, salur, pengasuh, a...
# 3    [heboh, video, gadis, ditelanjangidipukul, lak...
# 4    [satria, mahathir, cogil, sangka, keroyok, ana...
# Name: Berita, dtype: object

# %%
df['Berita'].apply(type).value_counts()
# Out:
# Berita
# <class 'list'>    49
# Name: count, dtype: int64

# %% [markdown]
# ### Flatten the tokens (Make single list)

# %%
flattened_tokens = [token for tokens in df['Berita'] for token in tokens]
print(flattened_tokens)
# Out:
# ['perkosa', 'anak', 'kandung', 'pria', 'dompu', 'tangkap', 'pria', 'inisial', 'am', 'kabupaten', 'dompu', 'nusa', 'tenggara', 'barat', 'ntb', 'tangkap', 'duga', 'perkosa', 'anak', 'kandung', 'tangkap', 'polisi', 'lapor', 'warga', 'kasi', 'humas', 'polres', 'dompu', 'ipda', 'zuharis', 'am', 'tangkap', 'rumah', 'tangkap', 'am', 'polisi', 'malam', 'iya', 'tangkap', 'malam', 'rabu', 'zuharis', 'detikbali', 'kamis', 'zuharis', 'rinci', 'kronologi', 'aksi', 'bejat', 'pria', 'sebut', 'tugas', 'susun', 'lapor', 'tunggu', 'lapor', 'lengkap', 'ya', 'salah', 'warga', 'rumah', 'korban', 'ahmad', 'tangkap', 'am', 'warga', 'heboh', 'warga', 'geram', 'am', 'tega', 'buat', 'asusila', 'anak', 'kandung', 'heboh', 'malam', 'warga', 'kerumun', 'cepat', 'aman', 'polisi', 'laku', 'am', 'milik', 'orang', 'anak', 'perempuan', 'aksi', 'bejat', 'am', 'rumahnyaada', 'anak', 'istri', 'habis', 'pikir', 'jadi', 'pria', 'cabul', 'anak', 'lelaki', 'rumdis', 'wabup', 'langkat', 'adik', 'anggota', 'dprd', 'pria', 'inisial', 'zs', 'lapor', 'leceh', 'seksual', 'cabul', 'anak', 'lelaki', 'rumah', 'dinas', 'rumdis', 'wakil', 'bupati', 'langkat', 'adik', 'anggota', 'dprd', 'langkat', 'polisi', 'proses', 'lapor', 'korbaniya', 'adik', 'zs', 'f', 'anggota', 'dprd', 'langkat', 'detiksumut', 'jumat', 'lindung', 'zs', 'proses', 'hukum', 'dukung', 'buat', 'zs', 'lindung', 'dukung', 'buat', 'biar', 'proses', 'hukum', 'jalan', 'aku', 'serah', 'zs', 'wajib', 'ada', 'zs', 'lacak', 'ada', 'adik', 'ada', 'lacak', 'berita', 'kasat', 'reskrim', 'polres', 'langkat', 'akp', 'dedi', 'mirza', 'korban', 'usia', 'lapor', 'kait', 'jadi', 'alami', 'korban', 'polres', 'langkat', 'jadi', 'ya', 'terima', 'lapor', 'desember', 'dedi', 'detiksumut', 'kamis', 'korban', 'lapor', 'dedi', 'langsung', 'lidi', 'polisi', 'ecek', 'jadi', 'perkara', 'tkp', 'periksa', 'korban', 'saksi', 'saksi', 'periksa', 'inti', 'korban', 'alami', 'leceh', 'keras', 'seksual', 'rumah', 'dinas', 'wakil', 'bupati', 'langkat', 'kosong', 'situ', 'tetap', 'sangka', 'aku', 'laku', 'tangkap', 'tahap', 'tetap', 'sangka', 'pasti', 'laku', 'buru', 'samping', 'korban', 'traumatik', 'damping', 'instansi', 'kait', 'trauma', 'healing', 'buka', 'korban', 'lapor', 'pasti', 'proses', 'korban', 'tutup', 'muncul', 'klarifikasi', 'duga', 'salur', 'pengasuh', 'anak', 'aghnia', 'punjabi', 'damping', 'aniaya', 'baby', 'sitter', 'timpa', 'jana', 'amira', 'priyanka', 'akrab', 'sapa', 'cana', 'anak', 'perempuan', 'selebgram', 'malang', 'emy', 'aghnia', 'siksa', 'aghnia', 'jam', 'unggah', 'aghnia', 'aku', 'ambil', 'pengasuh', 'salur', 'kenal', 'surabaya', 'aghnia', 'sebut', 'gamblang', 'nama', 'salur', 'tersebutkini', 'muncul', 'unggah', 'kait', 'klarifikasi', 'duga', 'salur', 'baby', 'sitter', 'timpa', 'emyaghnia', 'putri', 'cana', 'val', 'the', 'consultant', 'maaf', 'menyesalkn', 'jadi', 'tulis', 'akun', 'instagram', 'valthe', 'consultant', 'kutip', 'sabtu', 'salur', 'lanjut', 'toleransi', 'bentuk', 'keras', 'asuh', 'anak', 'jadi', 'coreng', 'salah', 'nilai', 'milik', 'usaha', 'tanam', 'layan', 'jadi', 'rugi', 'citra', 'ribu', 'kerja', 'usaha', 'gerak', 'bidang', 'sedia', 'titip', 'anak', 'dukung', 'selesai', 'bantu', 'proses', 'hukum', 'mesti', 'usaha', 'salur', 'tulis', 'pengasuh', 'anak', 'sejati', 'percaya', 'andal', 'orang', 'tua', 'anak', 'rumah', 'kerja', 'jalan', 'tugas', 'laku', 'hati', 'senantiasa', 'pegang', 'teguh', 'prinsip', 'hal', 'ibadah', 'stop', 'child', 'abuse', 'hormat', 'manajemen', 'pt', 'val', 'konsultan', 'indonesia', 'nyata', 'klarifikasi', 'unggah', 'feed', 'instagram', 'pantau', 'tutup', 'kolom', 'komentar', 'usaha', 'unggah', 'nyata', 'singkat', 'instagram', 'stories', 'emy', 'aghnia', 'heboh', 'media', 'sosial', 'akibat', 'siksa', 'putri', 'babak', 'bur', 'aniaya', 'subuh', 'pintu', 'kamar', 'kunci', 'rapat', 'sang', 'anak', 'lari', 'kejar', 'aniaya', 'anak', 'aghnia', 'tindih', 'badan', 'siram', 'cair', 'minyak', 'kutuskutus', 'aghnia', 'sebut', 'polisi', 'tega', 'hasil', 'rekam', 'cctv', 'aniaya', 'henti', 'cana' ...

# %% [markdown]
# ## Create vocabulary mapping from words to unique ids

# %%
def create_vocabulary(tokens):
    word_count = defaultdict(int)
    for token in tokens:
        word_count[token] += 1
    word_to_id = {word: i for i, (word, _) in enumerate(word_count.items())}
    id_to_word = {i: word for word, i in word_to_id.items()}
    return word_to_id, id_to_word

# %%
word_to_id, id_to_word = create_vocabulary(flattened_tokens)
word_to_id
# Out:
# {'perkosa': 0,
#  'anak': 1,
#  'kandung': 2,
#  'pria': 3,
#  'dompu': 4,
#  'tangkap': 5,
#  'inisial': 6,
#  'am': 7,
#  'kabupaten': 8,
#  'nusa': 9,
#  'tenggara': 10,
#  'barat': 11,
#  'ntb': 12,
#  'duga': 13,
#  'polisi': 14,
#  'lapor': 15,
#  'warga': 16,
#  'kasi': 17,
#  'humas': 18,
#  'polres': 19,
#  'ipda': 20,
#  'zuharis': 21,
#  'rumah': 22,
#  'malam': 23,
#  'iya': 24,
#  'rabu': 25,
#  'detikbali': 26,
#  'kamis': 27,
#  'rinci': 28,
#  'kronologi': 29,
#  'aksi': 30,
#  'bejat': 31,
#  'sebut': 32,
#  'tugas': 33,
#  'susun': 34,
#  'tunggu': 35,
#  'lengkap': 36,
#  'ya': 37,
#  'salah': 38,
#  'korban': 39,
#  'ahmad': 40,
#  'heboh': 41,
#  'geram': 42,
#  'tega': 43,
#  'buat': 44,
#  'asusila': 45,
#  'kerumun': 46,
#  'cepat': 47,
#  'aman': 48,
#  'laku': 49,
#  'milik': 50,
#  'orang': 51,
#  'perempuan': 52,
#  'rumahnyaada': 53,
#  'istri': 54,
#  'habis': 55,
#  'pikir': 56,
#  'jadi': 57,
#  'cabul': 58,
#  'lelaki': 59,
#  'rumdis': 60,
#  'wabup': 61,
#  'langkat': 62,
#  'adik': 63,
#  'anggota': 64,
#  'dprd': 65,
#  'zs': 66,
#  'leceh': 67,
#  'seksual': 68,
#  'dinas': 69,
#  'wakil': 70,
#  'bupati': 71,
#  'proses': 72,
#  'korbaniya': 73,
#  'f': 74,
#  'detiksumut': 75,
#  'jumat': 76,
#  'lindung': 77,
#  'hukum': 78,
#  'dukung': 79,
#  'biar': 80,
#  'jalan': 81,
#  'aku': 82,
#  'serah': 83,
#  'wajib': 84,
#  'ada': 85,
#  'lacak': 86,
#  'berita': 87,
#  'kasat': 88,
#  'reskrim': 89,
#  'akp': 90,
#  'dedi': 91,
#  'mirza': 92,
#  'usia': 93,
#  'kait': 94,
#  'alami': 95,
#  'terima': 96,
#  'desember': 97,
#  'langsung': 98,
#  'lidi': 99,
#  'ecek': 100,
#  'perkara': 101,
#  'tkp': 102,
#  'periksa': 103,
#  'saksi': 104,
#  'inti': 105,
#  'keras': 106,
#  'kosong': 107,
#  'situ': 108,
#  'tetap': 109,
#  'sangka': 110,
#  'tahap': 111,
#  'pasti': 112,
#  'buru': 113,
#  'samping': 114,
#  'traumatik': 115,
#  'damping': 116,
#  'instansi': 117,
#  'trauma': 118,
#  'healing': 119,
#  'buka': 120,
#  'tutup': 121,
#  'muncul': 122,
#  'klarifikasi': 123,
#  'salur': 124,
#  'pengasuh': 125,
#  'aghnia': 126,
#  'punjabi': 127,
#  'aniaya': 128,
#  'baby': 129,
#  'sitter': 130,
#  'timpa': 131,
#  'jana': 132,
#  'amira': 133,
#  'priyanka': 134,
#  'akrab': 135,
#  'sapa': 136,
#  'cana': 137,
#  'selebgram': 138,
#  'malang': 139,
#  'emy': 140,
#  'siksa': 141,
#  'jam': 142,
#  'unggah': 143,
#  'ambil': 144,
#  'kenal': 145,
#  'surabaya': 146,
#  'gamblang': 147,
#  'nama': 148,
#  'tersebutkini': 149,
#  'emyaghnia': 150,
#  'putri': 151,
#  'val': 152,
#  'the': 153,
#  'consultant': 154,
#  'maaf': 155,
#  'menyesalkn': 156,
#  'tulis': 157,
#  'akun': 158,
#  'instagram': 159,
#  'valthe': 160,
#  'kutip': 161,
#  'sabtu': 162,
#  'lanjut': 163,
#  'toleransi': 164,
#  'bentuk': 165,
#  'asuh': 166,
#  'coreng': 167,
#  'nilai': 168,
#  'usaha': 169,
#  'tanam': 170,
#  'layan': 171,
#  'rugi': 172,
#  'citra': 173,
#  'ribu': 174,
#  'kerja': 175,
#  'gerak': 176,
#  'bidang': 177,
#  'sedia': 178,
#  'titip': 179,
#  'selesai': 180,
#  'bantu': 181,
#  'mesti': 182,
#  'sejati': 183,
#  'percaya': 184,
#  'andal': 185,
#  'tua': 186,
#  'hati': 187,
#  'senantiasa': 188,
#  'pegang': 189,
#  'teguh': 190,
#  'prinsip': 191,
#  'hal': 192,
#  'ibadah': 193,
#  'stop': 194,
#  'child': 195,
#  'abuse': 196,
#  'hormat': 197,
#  'manajemen': 198,
#  'pt': 199,
#  'konsultan': 200,
#  'indonesia': 201,
#  'nyata': 202,
#  'feed': 203,
#  'pantau': 204,
#  'kolom': 205,
#  'komentar': 206,
#  'singkat': 207,
#  'stories': 208,
#  'media': 209,
#  'sosial': 210,
#  'akibat': 211,
#  'babak': 212,
#  'bur': 213,
#  'subuh': 214,
#  'pintu': 215,
#  'kamar': 216,
#  'kunci': 217,
#  'rapat': 218,
#  'sang': 219,
#  'lari': 220,
#  'kejar': 221,
#  'tindih': 222,
#  'badan': 223,
#  'siram': 224,
#  'cair': 225,
#  'minyak': 226,
#  'kutuskutus': 227,
#  'hasil': 228,
#  'rekam': 229,
#  'cctv': 230,
#  'henti': 231,
#  'luka': 232,
#  'lebam': 233,
#  'tubuh': 234,
#  'mata': 235,
#  'bengkak': 236,
#  'normal': 237,
#  'video': 238,
#  'gadis': 239,
#  'ditelanjangidipukul': 240,
#  'abg': 241,
#  'telanjang': 242,
#  'wanita': 243,
#  'dewasa': 244,
#  'palu': 245,
#  'sulawesi': 246,
#  'sulteng': 247,
#  'x': 248,
#  'langit': 249,
#  'ig': 250,
#  'hillarybrigittadalam': 251,
#  'edar': 252,
#  'diblur': 253,
#  'kondisi': 254,
#  'pukul': 255,
#  'videotampak': 256,
#  'angkat': 257,
#  'tangan': 258,
#  'gaun': 259,
#  'cokelat': 260,
#  'tendang': 261,
#  'korbankorban': 262,
#  'daya': 263,
#  'seret': 264,
#  'masuk': 265,
#  'kasubbid': 266,
#  'penmas': 267,
#  'bidhumas': 268,
#  'polda': 269,
#  'kompol': 270,
#  'sugeng': 271,
#  'lestari': 272,
#  'lurah': 273,
#  'tatura': 274,
#  'selatan': 275,
#  'camat': 276,
#  'maret': 277,
#  'personel': 278,
#  'polresta': 279,
#  'lokasi': 280,
#  'tkpsudah': 281,
#  'respons': 282,
#  'mei': 283,
#  'kemarin': 284,
#  'terang': 285,
#  'vs': 286,
#  'tahan': 287,
#  'kasubsi': 288,
#  'pidm': 289,
#  'aiptu': 290,
#  'kadek': 291,
#  'aruna': 292,
#  'detikcom': 293,
#  'sidik': 294,
#  'ppa': 295,
#  'satreskrim': 296,
#  'beber': 297,
#  'spa': 298,
#  'kota': 299,
#  'palulokasi': 300,
#  'bater': 301,
#  'play': 302,
#  'satria': 303,
#  'mahathir': 304,
#  'cogil': 305,
#  'keroyok': 306,
#  'kepri': 307,
#  'seleb': 308,
#  'tiktok': 309,
#  'barelang': 310,
#  'rekan': 311,
#  'kena': 312,
#  'baju': 313,
#  'warna': 314,
#  'oranye': 315,
#  'giring': 316,
#  'konferensi': 317,
#  'pers': 318,
#  'gelar': 319,
#  'tunduk': 320,
#  'hadir': 321,
#  'awak': 322,
#  'takut': 323,
#  'ruang': 324,
#  'dwi': 325,
#  'ramadhanto': 326,
#  'konfirmasi': 327,
#  'benar': 328,
#  'sm': 329,
#  'as': 330,
#  'dj': 331,
#  'rs': 332,
#  'ra': 333,
#  'tanggal': 334,
#  'nongkrong': 335,
#  'kafe': 336,
#  'kawasan': 337,
#  'tiban': 338,
#  'kupang': 339,
#  'batam': 340,
#  'senggol': 341,
#  'kelahi': 342,
#  'ramadanto': 343,
#  'jakarta': 344,
#  'giat': 345,
#  'info': 346,
#  'dalam': 347,
#  'besok': 348,
#  'yasin': 349,
#  'ringkus': 350,
#  'tiri': 351,
#  'umur': 352,
#  'tani': 353,
#  'mus': 354,
#  'rawas': 355,
#  'utara': 356,
#  'mura': 357,
#  'm': 358,
#  'alias': 359,
#  'my': 360,
#  'b': 361,
#  'ym': 362,
#  'kapolres': 363,
#  'akbp': 364,
#  'andi': 365,
#  'supriadi': 366,
#  'unit': 367,
#  'detiksumbagsel': 368,
#  'senin': 369,
#  'dasar': 370,
#  'desa': 371,
#  'tegal': 372,
#  'rejo': 373,
#  'tugumulyo': 374,
#  'barubaru': 375,
#  'kumpul': 376,
#  'alat': 377,
#  'bukti': 378,
#  'lawan': 379,
#  'kantor': 380,
#  'keluarga': 381,
#  'kades': 382,
#  'mempertanggungjawabkan': 383,
#  'tindak': 384,
#  'pidana': 385,
#  'sangkut': 386,
#  'ancam': 387,
#  'pasal': 388,
#  'uu': 389,
#  'ri': 390,
#  'nomor': 391,
#  'atur': 392,
#  'perintah': 393,
#  'anti': 394,
#  'ubah': 395,
#  'viral': 396,
#  'ayah': 397,
#  'probolinggo': 398,
#  'banting': 399,
#  'pinggir': 400,
#  'rayadalam': 401,
#  'durasi': 402,
#  'detik': 403,
#  'tarik': 404,
#  'motor': 405,
#  'berkalikali': 406,
#  'gendong': 407,
#  'pos': 408,
#  'sabhara': 409,
#  'panglima': 410,
#  'sudirman': 411,
#  'jati': 412,
#  'mayang': 413,
#  'supriyadi': 414,
#  'suara': 415,
#  'jerit': 416,
#  'tangis': 417,
#  'dengar': 418,
#  'jauh': 419,
#  'pasang': 420,
#  'suamiistri': 421,
#  'bawa': 422,
#  'tahun': 423,
#  'si': 424,
#  'menang': 425,
#  'persis': 426,
#  'sebab': 427,
#  'dekat': 428,
#  'keponakan': 429,
#  'harap': 430,
#  'usut': 431,
#  'moga': 432,
#  'ketemu': 433,
#  'kasihan': 434,
#  'murid': 435,
#  'smp': 436,
#  'cilacap': 437,
#  'basis': 438,
#  'potong': 439,
#  'siswa': 440,
#  'samasama': 441,
#  'baris': 442,
#  'kelompok': 443,
#  'libat': 444,
#  'rundung': 445,
#  'top': 446,
#  'w': 447,
#  'plus': 448,
#  'k': 449,
#  'cuman': 450,
#  'mukulin': 451,
#  'guntar': 452,
#  'arif': 453,
#  'setyoko': 454,
#  'pesan': 455,
#  'beda': 456,
#  'motif': 457,
#  'anakanak': 458,
#  'ujarnyaguntar': 459,
#  'r': 460,
#  'tantang': 461,
#  'kelas': 462,
#  'adu': 463,
#  'kakak': 464,
#  'ngadu': 465,
#  'ditantangin': 466,
#  'diaduin': 467,
#  'dipukulin': 468,
#  'teman': 469,
#  'sorot': 470,
#  'ajar': 471,
#  'kasus': 472,
#  'bullying': 473,
#  'perundunganberkelahi': 474,
#  'adegan': 475,
#  'mbales': 476,
#  'balas': 477,
#  'detikjateng': 478,
#  'via': 479,
#  'whatsapp': 480,
#  'pagi': 481,
#  'kali': 482,
#  'cimanggu': 483,
#  'guruortu': 484,
#  'bikin': 485,
#  'petisi': 486,
#  'kepala': 487,
#  'sma': 488,
#  'aru': 489,
#  'copot': 490,
#  'pulau': 491,
#  'malu': 492,
#  'guru': 493,
#  'menandatangani': 494,
#  'pj': 495,
#  'gubernur': 496,
#  'sadali': 497,
#  'ie': 498,
#  'oknum': 499,
#  'sekolah': 500,
#  'wd': 501,
#  'jabat': 502,
#  'pindah': 503,
#  'total': 504,
#  'ganti': 505,
#  'sarana': 506,
#  'prasarana': 507,
#  'martha': 508,
#  'mantayborbir': 509,
#  'alas': 510,
#  'tanda': 511,
#  'minggu': 512,
#  'upaya': 513,
#  'selamat': 514,
#  'dunia': 515,
#  'didik': 516,
#  'tenaga': 517,
#  'pendidik': 518,
#  'berani': 519,
#  'adil': 520,
#  'timbang': 521,
#  'sanksi': 522,
#  'nonaktif': 523,
#  'ganggu': 524,
#  'psikologi': 525,
#  'aktivitas': 526,
#  'nyaman': 527,
#  'harapnyalebih': 528,
#  'pilih': 529,
#  'kapolda': 530,
#  'asn': 531,
#  'honorer': 532,
#  'dua': 533,
#  'masingmasing': 534,
#  'mcj': 535,
#  'mcw': 536,
#  'od': 537,
#  'spkt': 538,
#  'lancar': 539,
#  'juli': 540,
#  'september': 541,
#  'kepsek': 542,
#  'bripka': 543,
#  'yubilino': 544,
#  'sahertian': 545,
#  'balikpapan': 546,
#  'selidik': 547,
#  'fisik': 548,
#  'kalimantan': 549,
#  'timur': 550,
#  'peran': 551,
#  'kadiv': 552,
#  'kombes': 553,
#  'yusuf': 554,
#  'sutejo': 555,
#  'wartawan': 556,
#  'hadap': 557,
#  'abh': 558,
#  'turut': 559,
#  'cari': 560,
#  'stakeholder': 561,
#  'ucapnyaadapun': 562,
#  'pihakpihak': 563,
#  'kadisdik': 564,
#  'korbanpelaku': 565,
#  'rencana': 566,
#  'dpakb': 567,
#  'belah': 568,
#  'sepakat': 569,
#  'damai': 570,
#  'masalah': 571,
#  'kembang': 572,
#  'narasi': 573,
#  'merah': 574,
#  'seragam': 575,
#  'pramuka': 576,
#  'duduk': 577,
#  'kursi': 578,
#  'jatuh': 579,
#  'lantai': 580,
#  'rintih': 581,
#  'tersebutkadiv': 582,
#  'pol': 583,
#  'masjid': 584,
#  'tpa': 585,
#  'darussalam': 586,
#  'bogor': 587,
#  'dalih': 588,
#  'rewel': 589,
#  'parung': 590,
#  'jawa': 591,
#  'emosi': 592,
#  'informasi': 593,
#  'sih': 594,
#  'mara': 595,
#  'wib': 596,
#  'bekas': 597,
#  'benda': 598,
#  'tumpul': 599,
#  'memar': 600,
#  'punggung': 601,
#  'pundakbekasbekas': 602,
#  'garis': 603,
#  'panjang': 604,
#  'titik': 605,
#  'pundak': 606,
#  'gorok': 607,
#  'tidur': 608,
#  'kabur': 609,
#  'a': 610,
#  'bunuh': 611,
#  'tidurperistiwa': 612,
#  'ciomas': 613,
#  'serang': 614,
#  'banten': 615,
#  'mapolresta': 616,
#  'kotainisial': 617,
#  'an': 618,
#  'kapolsek': 619,
#  'iptu': 620,
#  'fridy': 621,
#  'romadhon': 622,
#  'tewas': 623,
#  'leher': 624,
#  'senjata': 625,
#  'raja': 626,
#  'halusinasihalusinasi': 627,
#  'sembelih': 628,
#  'sunan': 629,
#  'kalijaga': 630,
#  'izin': 631,
#  'pulang': 632,
#  'bully': 633,
#  'sean': 634,
#  'putra': 635,
#  'mendapata': 636,
#  'ungkap': 637,
#  'ct': 638,
#  'scan': 639,
#  'alhamdulillah': 640,
#  'syukur': 641,
#  'studio': 642,
#  'trans': 643,
#  'tv': 644,
#  'selasa': 645,
#  'rawat': 646,
#  'dokter': 647,
#  'kasih': 648,
#  'obat': 649,
#  'satu': 650,
#  'kanan': 651,
#  'keluh': 652,
#  'betulbetul': 653,
#  'khawatir': 654,
#  'lupa': 655,
#  'basket': 656,
#  'bullyan': 657,
#  'protect': 658,
#  'support': 659,
#  'aja': 660,
#  'bu': 661,
#  'cianjur': 662,
#  'nasib': 663,
#  'psikis': 664,
#  'oknumgurusmancianjuryangpukulsiswanasib': 665,
#  'negeri': 666,
#  'jawabarat': 667,
#  'putus': 668,
#  'provinsi': 669,
#  'cabang': 670,
#  'wilayah': 671,
#  'v': 672,
#  'sman': 673,
#  'nonongwinarni': 674,
#  'kordinasi': 675,
#  'simpul': 676,
#  'dinaspendidikan': 677,
#  'ditindaklanjuti': 678,
#  'nonong': 679,
#  'konsekuensi': 680,
#  'batas': 681,
#  'tempat': 682,
#  'bidangbidang': 683,
#  'kegiatankegiatan': 684,
#  'sentuh': 685,
#  'hubung': 686,
#  'diaada': 687,
#  'faktor': 688,
#  'melatarbelakangi': 689,
#  'picu': 690,
#  'singgung': 691,
#  'paham': 692,
#  'sikap': 693,
#  'kendati': 694,
#  'syok': 695,
#  'luas': 696,
#  'mental': 697,
#  'bagus': 698,
#  'atlet': 699,
#  'silat': 700,
#  'ekskul': 701,
#  'lainlain': 702,
#  'wajar': 703,
#  'terkagetkaget': 704,
#  'imbuh': 705,
#  'harum': 706,
#  'taufik': 707,
#  'matematika': 708,
#  'xi': 709,
#  'astri': 710,
#  'culik': 711,
#  'majikan': 712,
#  'bandung': 713,
#  'rp': 714,
#  'juta': 715,
#  'bui': 716,
#  'fauziah': 717,
#  'asisten': 718,
#  'tangga': 719,
#  'art': 720,
#  'gegara': 721,
#  'uang': 722,
#  'tebus': 723,
#  'culi': 724,
#  'november': 725,
#  'cikutra': 726,
#  'balita': 727,
#  'pacar': 728,
#  'ganjar': 729,
#  'kapolrestabes': 730,
#  'budi': 731,
#  'sartono': 732,
#  'lilit': 733,
#  'utang': 734,
#  'nekat': 735,
#  'ka': 736,
#  'bekerjasama': 737,
#  'g': 738,
#  'angkut': 739,
#  'jurus': 740,
#  'ledeng': 741,
#  'setiabudi': 742,
#  'temu': 743,
#  'sepeda': 744,
#  'daerah': 745,
#  'parongpong': 746,
#  'baratdisana': 747,
#  'beli': 748,
#  'kartu': 749,
#  'sim': 750,
#  'kembali': 751,
#  'turun': 752,
#  'harga': 753,
#  'gang': 754,
#  'linmas': 755,
#  'untung': 756,
#  'bicara': 757,
#  'antar': 758,
#  'telusur': 759,
#  'ciduk': 760,
#  'kbb': 761,
#  'jerat': 762,
#  'jo': 763,
#  'undangundang': 764,
#  'maksimal': 765,
#  'kurung': 766,
#  'penjara': 767,
#  'jaksel': 768,
#  'temperamental': 769,
#  'rsj': 770,
#  'jagakarsa': 771,
#  'ty': 772,
#  'kerap': 773,
#  'parah': 774,
#  'temperamen': 775,
#  'kasar': 776,
#  'metro': 777,
#  'bintoro': 778,
#  'sakit': 779,
#  'jiwa': 780,
#  'darmawangsa': 781,
#  'peristiwa': 782,
#  'tinggal': 783,
#  'hari': 784,
#  'telah': 785,
#  'awat': 786,
#  'sakitpolisi': 787,
#  'gegar': 788,
#  'otak': 789,
#  'benjol': 790,
#  'mati': 791,
#  'tolak': 792,
#  'autopsi': 793,
#  'minta': 794,
#  'visum': 795,
#  'kendala': 796,
#  'eyang': 797,
#  'berat': 798,
#  'bilang': 799,
#  'ubin': 800,
#  'fakta': 801,
#  'baru': 802,
#  'paman': 803,
#  'nian': 804,
#  'korbananak': 805,
#  'ibu': 806,
#  'ungsi': 807,
#  'tegalsari': 808,
#  'rusunawa': 809,
#  'nenek': 810,
#  'huni': 811,
#  'bibi': 812,
#  'saudara': 813,
#  'sepupu': 814,
#  'sn': 815,
#  'suami': 816,
#  'mi': 817,
#  'cecar': 818,
#  'me': 819,
#  'mna': 820,
#  'desak': 821,
#  'terus': 822,
#  'bapak': 823,
#  'suka': 824,
#  'payudara': 825,
#  'tekan': 826,
#  'apa': 827,
#  'jawab': 828,
#  'khilaf': 829,
#  'detikjatim': 830,
#  'i': 831,
#  'mr': 832,
#  'nggak': 833,
#  'sengaja': 834,
#  'megang': 835,
#  'canda': 836,
#  'marah': 837,
#  'sambung': 838,
#  'anggap': 839,
#  'bapake': 840,
#  'darah': 841,
#  'sesal': 842,
#  'niat': 843,
#  'nakal': 844,
#  'snsn': 845,
#  'ar': 846,
#  'lakilakinya': 847,
#  'polisisn': 848,
#  'puji': 849,
#  'sibuk': 850,
#  'jarang': 851,
#  'kuli': 852,
#  'bangun': 853,
#  'kontrak': 854,
#  'pemkot': 855,
#  'jual': 856,
#  'martabak': 857,
#  'restoran': 858,
#  'runding': 859,
#  'akses': 860,
#  'larang': 861,
#  'atas': 862,
#  'situasi': 863,
#  'temanteman': 864,
#  'bolos': 865,
#  'panggil': 866,
#  'pendam': 867,
#  'senyum': 868,
#  'snpolisi': 869,
#  'empat': 870,
#  'perpu': 871,
#  'cerita': 872,
#  'jemput': 873,
#  'risiko': 874,
#  'ringan': 875,
#  'pas': 876,
#  'kooperatif': 877,
#  'nang': 878,
#  'mojokerto': 879,
#  'minggat': 880,
#  'rumahnyakepala': 881,
#  'ari': 882,
#  'widiastuti': 883,
#  'siswi': 884,
#  'kranggan': 885,
#  'pergi': 886,
#  'buah': 887,
#  'mojosari': 888,
#  'tahunibu': 889,
#  'ajak': 890,
#  'alihalih': 891,
#  'lega': 892,
#  'kaget': 893,
#  'dhimas': 894,
#  'veha': 895,
#  'yogatama': 896,
#  'daditunggal': 897,
#  'ploso': 898,
#  'jombang': 899,
#  'pujasera': 900,
#  'bangsal': 901,
#  'esok': 902,
#  'jumpa': 903,
#  'harmunanda': 904,
#  'afiq': 905,
#  'ramadhan': 906,
#  'nanda': 907,
#  'magersari': 908,
#  'mojokertoari': 909,
#  'karyawan': 910,
#  'kantong': 911,
#  'dekam': 912,
#  'rutan': 913,
#  'ayat': 914,
#  'palembang': 915,
#  'remaja': 916,
#  'kubur': 917,
#  'candu': 918,
#  'film': 919,
#  'sumatera': 920,
#  'bincang': 921,
#  'aa': 922,
#  'makam': 923,
#  'tpu': 924,
#  'talang': 925,
#  'kerikil': 926,
#  'pakai': 927,
#  'olahraga': 928,
#  'rudapaksa': 929,
#  'is': 930,
#  'mz': 931,
#  'ms': 932,
#  'jasad': 933,
#  'ibunda': 934,
#  'winarti': 935,
#  'pamit': 936,
#  'berangkat': 937,
#  'tibatiba': 938,
#  'ngomong': 939,
#  'kabar': 940,
#  'panik': 941,
#  'jenazah': 942,
#  'jaya': 943,
#  'mantan': 944,
#  'tahundugaan': 945,
#  'pegawai': 946,
#  'suku': 947,
#  'madam': 948,
#  'bakar': 949,
#  'postingan': 950,
#  'vital': 951,
#  'inap': 952,
#  'cerai': 953,
#  'diam': 954,
#  'alam': 955,
#  'tersebutibu': 956,
#  'psikolog': 957,
#  'jayadimintai': 958,
#  'kabid': 959,
#  'ade': 960,
#  'ary': 961,
#  'syam': 962,
#  'indradi': 963,
#  'damkar': 964,
#  'februari': 965,
#  'saudari': 966,
#  'pa': 967,
#  'cipayung': 968,
#  'subdit': 969,
#  'renakta': 970,
#  'ditreskrimum': 971,
#  'bap': 972,
#  'pungkas': 973,
#  'redaksi': 974,
#  'dki': 975,
#  'tanggap': 976,
#  'muat': 977,
#  'bus': 978,
#  'serpong': 979,
#  'school': 980,
#  'kronologis': 981,
#  'dapat': 982,
#  'tangerang': 983,
#  'alvino': 984,
#  'cahyadi': 985,
#  'gali': 986,
#  'buktibukti': 987,
#  'internasional': 988,
#  'dibully': 989,
#  'senior': 990,
#  'geng': 991,
#  'panas': 992,
#  'kanit': 993,
#  'tangsel': 994,
#  'galih': 995,
#  'miris': 996,
#  'maros': 997,
#  'sulsel': 998,
#  'es': 999,
#  ...}

# %% [markdown]
# ## Generate Training Data

# %% [markdown]
# <p> Melihat kata y dan kata konteksnya. Dia berlaku iterasi jadi kata y bisa juga menjadi kata konteks </p>

# %%
def generate_training_data(data, word_to_id, window_size):
    """Generate training data as context-y pairs."""
    training_data = []
    for tokens in data:
        for i, word in enumerate(tokens):
            start = max(0, i - window_size)
            end = min(len(tokens), i + window_size + 1)
            for j in range(start, end):
                if i != j:
                    training_data.append((word_to_id[word], word_to_id[tokens[j]]))
    return training_data

# %%
window_size = 2
training_data = generate_training_data(df['Berita'], word_to_id, window_size)
training_data
# Out:
# [(0, 1),
#  (0, 2),
#  (1, 0),
#  (1, 2),
#  (1, 3),
#  (2, 0),
#  (2, 1),
#  (2, 3),
#  (2, 4),
#  (3, 1),
#  (3, 2),
#  (3, 4),
#  (3, 5),
#  (4, 2),
#  (4, 3),
#  (4, 5),
#  (4, 3),
#  (5, 3),
#  (5, 4),
#  (5, 3),
#  (5, 6),
#  (3, 4),
#  (3, 5),
#  (3, 6),
#  (3, 7),
#  (6, 5),
#  (6, 3),
#  (6, 7),
#  (6, 8),
#  (7, 3),
#  (7, 6),
#  (7, 8),
#  (7, 4),
#  (8, 6),
#  (8, 7),
#  (8, 4),
#  (8, 9),
#  (4, 7),
#  (4, 8),
#  (4, 9),
#  (4, 10),
#  
#  (39, 115),
#  (39, 116),
#  (115, 114),
#  (115, 39),
#  (115, 116),
#  (115, 117),
#  (116, 39),
#  (116, 115),
#  (116, 117),
#  (116, 94),
#  (117, 115),
#  (117, 116),
#  (117, 94),
#  (117, 118),
#  (94, 116),
#  (94, 117),
#  (94, 118),
#  (94, 119),
#  (118, 117),
#  (118, 94),
#  (118, 119),
#  (118, 120),
#  (119, 94),
#  (119, 118),
#  (119, 120),
#  (119, 39),
#  (120, 118),
#  (120, 119),
#  (120, 39),
#  (120, 15),
#  (39, 119),
#  (39, 120),
#  (39, 15),
#  (39, 112),
#  (15, 120),
#  (15, 39),
#  (15, 112),
#  (15, 72),
#  (112, 39),
#  (112, 15),
#  (112, 72),
#  (112, 39),
#  (72, 15),
#  (72, 112),
#  (72, 39),
#  (72, 121),
#  (39, 112),
#  (39, 72),
#  (39, 121),
#  (121, 72),
#  (121, 39),
#  (122, 123),
#  (122, 13),
#  (123, 122),
#  (123, 13),
#  (123, 124),
#  (13, 122),
#  (13, 123),
#  (13, 124),
#  (13, 125),
#  (124, 123),
#  (124, 13),
#  (124, 125),
#  (124, 1),
#  (125, 13),
#  (125, 124),
#  (125, 1),
#  (125, 126),
#  (1, 124),
#  (1, 125),
#  (1, 126),
#  (1, 127),
#  (126, 125),
#  (126, 1),
#  (126, 127),
#  (126, 116),
#  (127, 1),
#  (127, 126),
#  (127, 116),
#  (127, 128),
#  (116, 126),
#  (116, 127),
#  (116, 128),
#  (116, 129),
#  (128, 127),
#  (128, 116),
#  (128, 129),
#  (128, 130),
#  (129, 116),
#  (129, 128),
#  (129, 130),
#  (129, 131),
#  (130, 128),
#  (130, 129),
#  (130, 131),
#  ...]

# %% [markdown]
# ### Initialize weights for the Word2Vec model

# %%
def initialize_weights(vocab_size, embedding_dim):
    w = np.random.rand(vocab_size, embedding_dim)  # Input weights
    v = np.random.rand(embedding_dim, vocab_size)  # Output weights
    return w, v

# %%
w, v = initialize_weights(len(word_to_id), embedding_dim=100)

# %%
w.shape
# Out:
# (1867, 100)

# %%
v.shape
# Out:
# (100, 1867)

# %%
def one_hot_encode(id, vocab_size):
    """Perform one-hot encoding for a given ID."""
    res = [0] * vocab_size
    res[id] = 1
    return res

# %%
def softmax(x):
    """Compute the softmax of a vector."""
    exp_x = np.exp(x - np.max(x))  # Subtract max(x) to improve stability
    return exp_x / np.sum(exp_x)

# %% [markdown]
# ## Neural Network word2Vec

# %%
def forward_propagation(word, w, v):
    """Perform forward propagation."""
    """
    Perform the forward propagation step.
    Args:
    - word: index of the y word
    - w: input-to-hidden weight matrix
    - v: hidden-to-output weight matrix
    
    Returns:
    - hidden: hidden layer activation (embedding vector)
    - predicted: predicted probability distribution (output layer)
    """

    # Input Layer
    X = one_hot_encode(word, len(w))
    
    # Hidden Layer          # Shape (100, )
    A = np.dot(X, w)

    # Hidden 2 (Output)
    B = np.dot(A, v)     # Shape (381, )
    Z = softmax(B)         # Shape (381, )

    return A, B, Z

# %%
def backward_propagation(word, context, A, Z, w, v, learning_rate):
    """Perform backward propagation"""
    """
    Perform the backward propagation step and update weights.
    Args:
    - word: index of the y word
    - context: index of the context word
    - hidden: hidden layer activation (embedding vector)
    - predicted: predicted probability distribution (output layer)
    - w: input-to-hidden weight matrix
    - v: hidden-to-output weight matrix
    - learning_rate: learning rate for gradient updates
    
    Returns:
    - Updated w and v
    """

    y = one_hot_encode(context, len(w))

    dB = Z - y
    dv = np.outer(A, dB)      # Shape (100, 381)
    dA = np.dot(dB, v.T)     # Shape (100,)
    dw = np.outer(dA, one_hot_encode(word, len(w))).T # (100,381)

    """Update weights"""
    w -= learning_rate * dw
    v -= learning_rate * dv
    return w, v

# %%
def train_word2vec(training_data, w, v, learning_rate, epochs):
    """Train the Word2Vec model using the provided training data."""
    """
    Train the Word2Vec model using forward and backward propagation.
    Args:
    - training_data: list of (y, context) pairs
    - w: input-to-hidden weight matrix
    - v: hidden-to-output weight matrix
    - learning_rate: learning rate for gradient updates
    - epochs: number of training iterations
    
    Returns:
    - Trained w and v
    """
    for epoch in range(epochs):
        total_loss = 0  # Initialize total loss for the epoch
        for word, context in training_data:
            # Forward pass
            A, B, Z = forward_propagation(word, w, v)
            
            # Compute loss (cross-entropy loss)
            y = one_hot_encode(context, len(w))
            L = -np.sum(y * np.log(Z + 1e-9))  # Adding 1e-9 for numerical stability
            total_loss += L
            
            # Backward pass
            w, v = backward_propagation(word, context, A, Z, w, v, learning_rate)
        
        # Print loss for the current epoch
        print(f"Epoch {epoch + 1}/{epochs}, Loss: {total_loss:.4f}")
    
    return w, v

# %%
train_word2vec(training_data, w, v, learning_rate=0.01, epochs=10)
# Out:
# Epoch 1/10, Loss: 223009.8803
# Epoch 2/10, Loss: 208914.4440
# Epoch 3/10, Loss: 202410.6566
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 train_word2vec(training_data, w, v, learning_rate=0.01, epochs=10)
#
# Cell In[18], line 23, in train_word2vec(training_data, w, v, learning_rate, epochs)
#      21 # Compute loss (cross-entropy loss)
#      22 y = one_hot_encode(context, len(w))
# ---> 23 L = -np.sum(y * np.log(Z + 1e-9))  # Adding 1e-9 for numerical stability
#      24 total_loss += L
#      26 # Backward pass
#
# KeyboardInterrupt:

# %%
#w
# Out:
# array([[ 0.33873711, -0.13408298,  0.00607258, ..., -0.01951817,
#          0.22225208, -0.49043355],
#        [ 0.11687252,  0.2034469 ,  0.26760142, ..., -0.05551917,
#          0.01819217, -0.23282326],
#        [ 0.54133126,  0.00577759,  0.53093181, ...,  0.0988413 ,
#         -0.24090315, -0.35099139],
#        ...,
#        [ 0.7348749 ,  0.50175242,  0.37687409, ...,  0.39741863,
#          0.385695  ,  0.05497061],
#        [ 0.5520787 ,  0.09674647,  0.52441286, ...,  0.79849027,
#          0.68788005,  0.17259819],
#        [ 0.43049079,  0.14151292,  0.52916242, ...,  0.22206568,
#          0.58070342,  0.89463913]])

# %%
#v
# Out:
# array([[ 0.35032911,  0.87536514,  0.34931059, ...,  1.10182228,
#          0.95541663,  0.96919229],
#        [ 0.40360829,  0.42553825,  0.25976093, ..., -0.22064363,
#          0.01718495,  0.62859583],
#        [ 0.44722416,  0.95264522,  0.49084048, ...,  0.18837631,
#          0.0229247 ,  0.23258476],
#        ...,
#        [ 0.31209222,  0.17208014,  0.4420775 , ...,  0.84851963,
#          1.03898032, -0.13980799],
#        [ 0.58351097,  0.15011712,  0.50890513, ...,  0.2980816 ,
#         -0.28580361,  0.61069594],
#        [ 0.15186599,  0.38157011,  0.1528174 , ...,  0.61187116,
#          0.73713281,  1.07906275]])

# %%
def aggregate_vectors_per_document(data, w, word_to_id):
    V = []
    for tokens in data:
        token_indices = [word_to_id[word] for word in tokens if word in word_to_id] #id setiap kata per dokumen
        #print("Token indices:", token_indices)
        doc_vector = np.mean(w[token_indices], axis=0) #rata-rata vektor per dokumen 
        V.append(doc_vector)
    return np.array(V)

# Hitung vektor dokumen
V = aggregate_vectors_per_document(df['Berita'], w, word_to_id)
# Out:
# array([[0.35328689, 0.38188585, 0.36088204, 0.3926816 , 0.34539149,
#         0.28964305, 0.34815066, 0.39979946, 0.35722227, 0.31163451,
#         0.34769791, 0.37611829, 0.41046073, 0.3152673 , 0.32829925,
#         0.36282047, 0.38433664, 0.38134284, 0.33544798, 0.38105525,
#         0.32940771, 0.35073623, 0.31419185, 0.33986089, 0.37987728,
#         0.37810579, 0.26429667, 0.35449624, 0.3658832 , 0.32561927,
#         0.40146074, 0.3263327 , 0.38280165, 0.32384681, 0.38186593,
#         0.36804312, 0.42102392, 0.34924557, 0.30808403, 0.29533136,
#         0.37098147, 0.32230914, 0.4049664 , 0.36153792, 0.33069211,
#         0.31732435, 0.33248184, 0.31004436, 0.36084785, 0.39417641,
#         0.34363397, 0.31197689, 0.24124766, 0.36411797, 0.28853914,
#         0.31743158, 0.36168025, 0.3819469 , 0.34319048, 0.31775364,
#         0.36563914, 0.35415113, 0.30222021, 0.30889231, 0.39477149,
#         0.38752017, 0.30915789, 0.31086074, 0.363947  , 0.37514209,
#         0.37588064, 0.33927625, 0.29478871, 0.3907921 , 0.32738311,
#         0.31761756, 0.31351739, 0.39506812, 0.29170798, 0.28965537,
#         0.30486549, 0.31292671, 0.3081334 , 0.35739777, 0.29044429,
#         0.37479538, 0.29816929, 0.33229906, 0.35178171, 0.32565591,
#         0.30147176, 0.30682271, 0.30028649, 0.37632503, 0.43550468,
#         0.32106179, 0.33820634, 0.29330606, 0.31125618, 0.30543465],
#        [0.30490162, 0.29333554, 0.27849947, 0.32668991, 0.39783081,
#         0.39962985, 0.30516521, 0.36466313, 0.27193108, 0.37110319,
#         0.38080184, 0.4037429 , 0.21026191, 0.32261199, 0.26916555,
#         0.35009864, 0.26080168, 0.39605993, 0.28696366, 0.16979368,
#         0.38667453, 0.4165847 , 0.31464566, 0.35077166, 0.39953523,
#         0.27231769, 0.37026148, 0.31905413, 0.29296741, 0.3048093 ,
#         0.21922007, 0.29251819, 0.28471801, 0.30745727, 0.33343553,
#         0.34667371, 0.31724084, 0.43147679, 0.2655762 , 0.21318577,
#         0.33961176, 0.36911023, 0.27629478, 0.31696509, 0.33668296,
#         0.28978344, 0.37712354, 0.35002227, 0.35958819, 0.33992899,
#         0.30298717, 0.33046096, 0.31437616, 0.34140495, 0.32646407,
#         0.48177061, 0.47800669, 0.27759392, 0.20755629, 0.32790513,
#         0.29641987, 0.3652792 , 0.28329961, 0.34469834, 0.3285596 ,
#         0.34450587, 0.32653475, 0.31980597, 0.27395226, 0.27773825,
#         0.34683427, 0.35508627, 0.41478566, 0.28876968, 0.31348599,
#         0.28892046, 0.346062  , 0.41899621, 0.28397985, 0.31262525,
#         0.25667761, 0.31094955, 0.31008342, 0.43151399, 0.28373742,
#         0.41106719, 0.35979567, 0.18636567, 0.31509853, 0.34194308,
#         0.32645646, 0.44726591, 0.32099004, 0.31391683, 0.34951736],
#        [0.27817209, 0.36719086, 0.44738311, 0.37825396, 0.37632131,
#         0.3637034 , 0.41592568, 0.31012295, 0.31463444, 0.28767196,
#         0.40777186, 0.4072959 , 0.23011646, 0.39623428, 0.34379135,
#         0.3569793 , 0.27518235, 0.35719596, 0.28024544, 0.3782671 ,
#         0.40000229, 0.37013325, 0.3294379 , 0.33396164, 0.4007948 ,
#         0.31554449, 0.33116779, 0.29414865, 0.26667313, 0.35480193,
#         0.26904038, 0.39282597, 0.41056008, 0.35503955, 0.28525957,
#         0.30907044, 0.3107936 , 0.31873603, 0.31986793, 0.38696237,
#         0.35834945, 0.29475675, 0.24902751, 0.355124  , 0.26448527,
#         0.29958972, 0.32178706, 0.36162514, 0.41899106, 0.36912219,
#         0.20744679, 0.31358178, 0.37783787, 0.29108789, 0.42601713,
#         0.34306233, 0.31029971, 0.24095698, 0.31735782, 0.28121859,
#         0.41197375, 0.34616731, 0.31843755, 0.26892962, 0.21291801,
#         0.38483127, 0.38278449, 0.37153705, 0.26838372, 0.31777357,
#         0.36596827, 0.26069948, 0.36468498, 0.33607672, 0.35115584,
#         0.35130849, 0.31234153, 0.32359579, 0.46209401, 0.31617313,
#         0.3233844 , 0.37926295, 0.32959249, 0.23998332, 0.32107623,
#         0.3470179 , 0.34420355, 0.32347674, 0.35324042, 0.40043301,
#         0.34809729, 0.25424983, 0.36569063, 0.31017107, 0.28682899,
#         0.34391519, 0.34042187, 0.31855852, 0.21867281, 0.40292565]])

# %%
# Tambahkan hasil agregasi ke dataframe dalam bentuk list agar bisa disimpan ke CSV
df['Word2Vec Vector'] = V.tolist()

# %%
df.head()
# Out:
#                                               Berita        Label  \
# 0  [faktafakta, santri, tewas, saksi, sangka, pon...        teman
# 1  [astri, culik, anak, majikan, bandung, rp, jut...     pengasuh
# 2  [polisi, keras, sma, bus, serpong, duga, kali,...        teman
# 3  [tega, bima, pukulgigit, anak, gegara, kesal, ...     keluarga
# 4  [polisi, tangkap, pria, duga, cabul, anak, sd,...  orang asing
#
#    Category_id                                    Word2Vec Vector
# 0            3  [0.3532868892949142, 0.3818858491610933, 0.360...
# 1            1  [0.3049016176906463, 0.29333553840422477, 0.27...
# 2            3  [0.32533741227239577, 0.36108487987479615, 0.3...
# 3            0  [0.2558586191227341, 0.4227631065065994, 0.374...
# 4            4  [0.2781720919008791, 0.36719086104651916, 0.44...

# %%
# Simpan ke dalam file CSV
output_file = 'Word2vec Vector.csv'
df.to_csv(output_file, index=False)
